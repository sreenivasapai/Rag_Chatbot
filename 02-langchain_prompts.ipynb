# %%
from langchain_ollama import ChatOllama

base_url = "http://localhost:11434"  # Ollama server
model = "gemma3:1b"  # the model you want to use

llm = ChatOllama(base_url=base_url, model=model)
# Out:
# c:\Users\sreen\OneDrive\Desktop\rag\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
question = "What is the capital of India?"
response = llm.invoke(question)
print(response.content)
# Out:
# The capital of India is **New Delhi**.
#
# It’s officially known as the Capital of India.

# %%
question = "Explain 3 interesting facts about Kerala"
response = llm.invoke(question)
print(response.content)
# Out:
# Okay, here are 3 interesting facts about Kerala, India, that go beyond the usual tourist highlights:
#
# 1. **Kerala is a Biodiversity Hotspot - And It’s Protected!**  Kerala is renowned for its incredible biodiversity, particularly its lush forests and diverse ecosystems. It's considered one of the most biodiverse states in India.  **Interesting Fact:**  It holds over 20% of India's total flowering plant species!  The state actively protects this biodiversity through a network of national parks, wildlife sanctuaries, and conservation efforts. This includes the Periyar National Park with its unique ecosystem, and the Vembanad Swamp – one of the largest peat swamps in India.
#
# ...

# %%
from langchain_core.messages import SystemMessage, HumanMessage

question = HumanMessage("Explain 3 interesting facts about Kerala")
system = SystemMessage("You are a school teacher.Answer like a student from school can undesrstand.")
response = llm.invoke([system, question])
print(response.content)

messages = [system,question]
print(f"questions: {question.content}" )
print(f"Response: {response.content}" )
# Out:
# Okay, here’s an explanation of 3 interesting facts about Kerala, like I'd explain it to a friend:
#
# **1. Kerala is Known as “The Spice Garden” – Seriously!**
#
# Okay, so you think Kerala is all beaches and backwaters? Yeah, that's part of it! But it’s *so* much more than just that.  Thousands of spices – cinnamon, cardamom, pepper, cloves – are grown there.  It’s like a giant spice farm, and they actually use them to make everything from tea and curry powder to perfumes and even medicines!  It's a huge part of Kerala’s culture and history.
#
# **2.  It’s Home to Ancient, Lush Forests and Wildlife!**
#
# Kerala has some seriously cool forests. Think of the Periyar National Park, where you can see elephants, tigers, and even leopards! It’s also got tons of waterfalls, and the forests are really old – some parts go back hundreds of years!  Plus, you’ll find lots of unique wildlife, like elephants, tigers, rhinos, and even the elusive Nilgiri Tahr (a mountain goat).
#
# ...

# %%
question = HumanMessage("Explain 3 interesting facts about Kerala")
system = SystemMessage("You are PHD Scholer and your audience are also phd scholers explain like they can understand.")
response = llm.invoke([system, question])
print(response.content)

messages = [system,question]
print(f"questions: {question.content}" )
print(f"Response: {response.content}" )
# Out:
# Alright, let’s dive into some fascinating facts about Kerala, a state brimming with history, culture, and a surprisingly dynamic economy. As we’re all tackling similar challenges and seeking novel insights, let’s approach this from a slightly elevated perspective – think of it as expanding the scope of what we already know. Here are three interesting facts, designed to spark your curiosity, and potentially lead to new research avenues:
#
# ...

# %%
from langchain_core.prompts import (
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
    PromptTemplate,
    ChatPromptTemplate,
)

system = SystemMessagePromptTemplate.from_template(
    "You are a {school} teacher. You answer in short sentences."
)

question = HumanMessagePromptTemplate.from_template(
    "Tell me about the {topics} in {points} points."
)

# %%
print(system)
print(question)
# Out:
# prompt=PromptTemplate(input_variables=['school'], input_types={}, partial_variables={}, template='You are a {school} teacher. You answer in short sentences.') additional_kwargs={}
# prompt=PromptTemplate(input_variables=['points', 'topics'], input_types={}, partial_variables={}, template='Tell me about the {topics} in {points} points.') additional_kwargs={}

# %%
question.format(topics="Earth", points=3)
# Out:
# HumanMessage(content='Tell me about the Earth in 3 points.', additional_kwargs={}, response_metadata={})

# %%
system.format(school="high school")
# Out:
# SystemMessage(content='You are a high school teacher. You answer in short sentences.', additional_kwargs={}, response_metadata={})

# %%
messages = [system,question]
template = chatpromptTemplate = ChatPromptTemplate(messages)
print(template)
# Out:
# input_variables=['points', 'school', 'topics'] input_types={} partial_variables={} messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['school'], input_types={}, partial_variables={}, template='You are a {school} teacher. You answer in short sentences.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['points', 'topics'], input_types={}, partial_variables={}, template='Tell me about the {topics} in {points} points.'), additional_kwargs={})]

# %%
question= template.invoke({'school':'high school',"topics":"Kerala","points":3})
responce = llm.invoke(question)
print(f"Response:{responce.content}")
# Out:
# Response:Okay, here’s a quick summary of Kerala in three points:
#
# 1.  It’s a coastal state with lush greenery.
# 2.  It’s known for its backwaters and spices.
# 3.  It has a rich culture and diverse traditions.
